# %%
# !pip install transformers
# !pip install --upgrade transformers
# !pip install transformers==4.41.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /home/ubuntu/.local/lib/python3.10/site-packages (4.57.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers) (5.4.1)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: tqdm>=4.27 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (0.36.0)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from transformers) (21.3)
# Requirement already satisfied: safetensors>=0.4.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: numpy>=1.17 in /usr/lib/python3/dist-packages (from transformers) (1.21.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/lib/python3/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.10.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/lib/python3/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2024.3.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /home/ubuntu/.local/lib/python3.10/site-packages (4.57.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in /usr/lib/python3/dist-packages (from transformers) (1.21.5)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (0.36.0)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from transformers) (21.3)
# Requirement already satisfied: safetensors>=0.4.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/lib/python3/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.10.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/lib/python3/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2024.3.1)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transformers==4.41.0
#   Downloading transformers-4.41.0-py3-none-any.whl (9.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 63.7 MB/s eta 0:00:0000:0100:01
# Collecting tokenizers<0.20,>=0.19
#   Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 136.4 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers==4.41.0) (2025.11.3)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from transformers==4.41.0) (2.25.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers==4.41.0) (5.4.1)
# Requirement already satisfied: safetensors>=0.4.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers==4.41.0) (0.7.0)
# Requirement already satisfied: numpy>=1.17 in /usr/lib/python3/dist-packages (from transformers==4.41.0) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from transformers==4.41.0) (21.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers==4.41.0) (0.36.0)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from transformers==4.41.0) (3.6.0)
# Requirement already satisfied: tqdm>=4.27 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers==4.41.0) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.0) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/lib/python3/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.0) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/lib/python3/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.0) (4.10.0)
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.3
#     Uninstalling transformers-4.57.3:
#       Successfully uninstalled transformers-4.57.3
# Successfully installed tokenizers-0.19.1 transformers-4.41.0

# %%
# !pip uninstall -y transformers
# !pip install --upgrade transformers
# Out:
# Found existing installation: transformers 4.41.0
# Uninstalling transformers-4.41.0:
#   Successfully uninstalled transformers-4.41.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transformers
#   Using cached transformers-4.57.3-py3-none-any.whl (12.0 MB)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (0.36.0)
# Requirement already satisfied: tqdm>=4.27 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: numpy>=1.17 in /usr/lib/python3/dist-packages (from transformers) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from transformers) (21.3)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers) (5.4.1)
# Collecting tokenizers<=0.23.0,>=0.22.0
#   Using cached tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Requirement already satisfied: regex!=2019.12.17 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/lib/python3/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/lib/python3/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.10.0)
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
# Successfully installed tokenizers-0.22.2 transformers-4.57.3

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_name = "Qwen/Qwen2.5-7B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto"
)

prompt_text = (
    "System: You are Qwen, created by Alibaba Cloud. You are a helpful assistant.\n"
    "User: Give me a short introduction to large language models.\n"
    "Assistant:"
)

inputs = tokenizer(prompt_text, return_tensors="pt").to(model.device)

generated_ids = model.generate(
    **inputs,
    max_new_tokens=512
)

response = tokenizer.decode(generated_ids[0], skip_special_tokens=True)
print(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py in getattribute_from_module(module, attr)
#     740         try:
# --> 741             return getattribute_from_module(transformers_module, attr)
#     742         except ValueError:
#
# ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py in getattribute_from_module(module, attr)
#     744     else:
# --> 745         raise ValueError(f"Could not find {attr} in {transformers_module}!")
#     746
#
# ValueError: Could not find Qwen2ForCausalLM in <module 'transformers' from '/home/ubuntu/.local/lib/python3.10/site-packages/transformers/__init__.py'>!
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5054/3780455694.py in <module>
#       5
#       6 tokenizer = AutoTokenizer.from_pretrained(model_name)
# ----> 7 model = AutoModelForCausalLM.from_pretrained(
#       8     model_name,
#       9     torch_dtype="auto",
#
# ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     599             )
#     600         elif type(config) in cls._model_mapping:
# --> 601             model_class = _get_model_class(config, cls._model_mapping)
#     602             if model_class.config_class == config.sub_configs.get("text_config", None):
#     603                 config = config.get_text_config()
#
# ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py in _get_model_class(config, model_mapping)
#     392
#     393 def _get_model_class(config, model_mapping):
# --> 394     supported_models = model_mapping[type(config)]
#     395     if not isinstance(supported_models, (list, tuple)):
#     396         return supported_models
#
# ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py in __getitem__(self, key)
#     805         if model_type in self._model_mapping:
#     806             model_name = self._model_mapping[model_type]
# --> 807             return self._load_attr_from_module(model_type, model_name)
#     808
#     809         # Maybe there was several model types associated with this config.
#
# ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py in _load_attr_from_module(self, model_type, attr)
#     819         if module_name not in self._modules:
#     820             self._modules[module_name] = importlib.import_module(f".{module_name}", "transformers.models")
# --> 821         return getattribute_from_module(self._modules[module_name], attr)
#     822
#     823     def keys(self) -> list[type[PretrainedConfig]]:
#
# ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py in getattribute_from_module(module, attr)
#     741             return getattribute_from_module(transformers_module, attr)
#     742         except ValueError:
# --> 743             raise ValueError(f"Could not find {attr} neither in {module} nor in {transformers_module}!")
#     744     else:
#     745         raise ValueError(f"Could not find {attr} in {transformers_module}!")
#
# ValueError: Could not find Qwen2ForCausalLM neither in <module 'transformers.models.qwen2' from '/home/ubuntu/.local/lib/python3.10/site-packages/transformers/models/qwen2/__init__.py'> nor in <module 'transformers' from '/home/ubuntu/.local/lib/python3.10/site-packages/transformers/__init__.py'>!
